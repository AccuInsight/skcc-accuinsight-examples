# %% [markdown]
# # Accuinsight+ Modeler AutoDL tutorial
# ## 스팸 계정과 정상 계정을 분류하는 MLP 모델
# ## 목차
# 1. [분석 개요](#mlp_분석개요)
# 2. [데이터](#mlp_데이터)
# 3. [MLP 모델 생성 및 학습](#mlp_모델_구성_및_학습)
# 4. [Modeler AutoDL 사용방법](#AutoDL_사용방법)

# %% [markdown]
# <a id='mlp_분석개요'></a>
# ## 분석 개요
# - 본 예제에서는 kaggle에서 제공하는 [인스타그램 데이터](https://www.kaggle.com/free4ever1/instagram-fake-spammer-genuine-accounts?select=train.csv)를 사용해 스팸 계정과 정상 계정을 분류하는 MLP 모델을 만들고,
#   Accuinsight+ Modeler의 AutoDL 기능을 사용하여 하이퍼파라미터를 최적화하는 과정을 설명합니다.([이미지 출처](https://www.intechopen.com/books/artificial-neural-networks-architectures-and-applications/mlp-and-anfis-applied-to-the-prediction-of-hole-diameters-in-the-drilling-process/))
# <p align="center">
#     <img src="pic/MLP.jpg" height="400px" width="500px">
# </p>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import easydict
import csv
from datetime import datetime, timezone

from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers, Input

# %% [markdown]
# <a id='mlp_데이터'></a>
# ## 데이터
# - 설명 변수는 총 11개로, 4개의 이진 변수를 포함하고 있습니다.
#   - 이진 변수: `profile pic`, `name==username`, `external URL`, `private`
# - 데이터의 클래스를 의미하는 변수는 `fake`이고 `fake`의 값이 1이면 스팸 계정이고 0이면 정상 계정입니다.

# %% [markdown]
# train 데이터를 불러옵니다.

# %%
train = pd.read_csv("data/instagram_train.csv")
train.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# 2         159        98     0
# 3         414       651     0
# 4         151       126     0

# %%
train['profile pic'] = train['profile pic'].astype('category')
train['name==username'] = train['name==username'].astype('category')
train['external URL'] = train['external URL'].astype('category')
train['private'] = train['private'].astype('category')

train_X = pd.get_dummies(train)
train_Y = train_X.pop("fake")

# %% [markdown]
# test 데이터를 불러옵니다.

# %%
test = pd.read_csv("data/instagram_test.csv")
test.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.33               1                  0.33
# 1            1                  0.00               5                  0.00
# 2            1                  0.00               2                  0.00
# 3            1                  0.00               1                  0.00
# 4            1                  0.50               1                  0.00
#
#    name==username  description length  external URL  private  #posts  \
# 0               1                  30             0        1      35
# 1               0                  64             0        1       3
# 2               0                  82             0        1     319
# 3               0                 143             0        1     273
# 4               0                  76             0        1       6
#
#    #followers  #follows  fake
# 0         488       604     0
# 1          35         6     0
# 2         328       668     0
# 3       14890      7369     0
# 4         225       356     0

# %%
test['profile pic'] = test['profile pic'].astype('category')
test['name==username'] = test['name==username'].astype('category')
test['external URL'] = test['external URL'].astype('category')
test['private'] = test['private'].astype('category')

test_X = pd.get_dummies(test)
test_Y = test_X.pop("fake")

# %% [markdown]
# 데이터 개수를 확인합니다.

# %%
print("총 데이터 개수: ", len(train) + len(test))
print("train 데이터 개수: ", len(train))
print("test 데이터 개수: ", len(test))
# Out:
# 총 데이터 개수:  696
# train 데이터 개수:  576
# test 데이터 개수:  120

# %% [markdown]
# <a id='mlp_모델_구성_및_학습'></a>
# ## MLP 모델 생성 및 학습

# %% [markdown]
# - 본 예제에서는 모델 학습과 관련된 하이퍼파라미터인 epochs, batch size, learning_rate와
#   모델 구조를 결정하는 하이퍼파라미터인 num_nodes와 num_layers를 최적화합니다.
#   - `num_nodes`: Hidden layer의 노드 개수
#   - `num_layers`: Hidden layer의 개수
# - AutoDL을 사용하기 위해서는 __argparse__를 통해 하이퍼파라미터를 설정해야 하는데,
#   jupyter notebook에서는 argparse 사용이 불가능하기 때문에 __easydict__를 통해 하이퍼파라미터를 설정합니다.
#   실제로 AutoDL에 사용되는 [autodl_mlp_user_classification.py](autodl_mlp_user_classification.py)에서는 argparse를 통해 하이퍼파라미터를 설정합니다.

# %%
args = easydict.EasyDict({
    "epochs": 100,
    "batch_size": 64,
    "learning_rate": 0.0001,
    "activation_func": 'relu',
    "num_nodes": 16,
    "num_layers": 2})

# %% [markdown]
# MLP 모델을 생성합니다.

# %%
model = tf.keras.Sequential()
model.add(Input(shape=(15,)))
for i in range(args.num_layers):
    model.add(Dense(args.num_nodes, activation=args.activation_func))
model.add(Dense(2, activation=args.activation_func))

# Adam optimizer를 사용합니다.
opt = optimizers.Adam(lr=args.learning_rate, amsgrad=True)
model.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 562
# Trainable params: 562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - AutoDL에서 평가 지표를 수집할 수 있도록 epoch이 종료될 때마다 평가 지표(Accuracy)를 출력합니다.
# - 이번 예제에서는 __평가 지표명=평가 지표값__ 형식으로 평가 지표를 출력하는데,
#   평가 지표 설정 방법은 [Modeler AutoDL 사용방법](#AutoDL_사용방법) 챕터에서 좀 더 자세히 다룰 것입니다.

# %%
class MetricHistory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        local_time = datetime.now(timezone.utc).astimezone().isoformat()
        print("\nEpoch {}".format(epoch + 1))
        print("{} Train-acc={:.4f}".format(local_time, logs['accuracy']))
        print("{} Validation-acc={:.4f}".format(local_time, logs['val_accuracy']))

history = MetricHistory()

model.fit(train_X.values, train_Y.values,
          epochs=args.epochs,
          batch_size=args.batch_size,
          validation_data=(test_X, test_Y),
          callbacks=[history])
# Out:
# Epoch 1/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.6845 - accuracy: 0.5938
# Epoch 1
# 2020-09-21T23:14:48.250296+09:00 Train-acc=0.5781
# 2020-09-21T23:14:48.250296+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 14ms/step - loss: 6.8033 - accuracy: 0.5781 - val_loss: 6.8933 - val_accuracy: 0.6167
# Epoch 2/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.0154 - accuracy: 0.6094
# Epoch 2
# 2020-09-21T23:14:48.304365+09:00 Train-acc=0.5816
# 2020-09-21T23:14:48.304365+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7881 - accuracy: 0.5816 - val_loss: 6.8415 - val_accuracy: 0.6167
# Epoch 3/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.4006 - accuracy: 0.5938
# Epoch 3
# 2020-09-21T23:14:48.454593+09:00 Train-acc=0.5868
# 2020-09-21T23:14:48.454593+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 16ms/step - loss: 6.7717 - accuracy: 0.5868 - val_loss: 6.8878 - val_accuracy: 0.6167
# Epoch 4/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1815 - accuracy: 0.6406
# Epoch 4
# 2020-09-21T23:14:48.506030+09:00 Train-acc=0.5868
# 2020-09-21T23:14:48.506030+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7168 - accuracy: 0.5868 - val_loss: 6.8855 - val_accuracy: 0.6167
# Epoch 5/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2993 - accuracy: 0.5781
# Epoch 5
# 2020-09-21T23:14:48.556966+09:00 Train-acc=0.5920
# 2020-09-21T23:14:48.556966+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7001 - accuracy: 0.5920 - val_loss: 6.8303 - val_accuracy: 0.6167
# Epoch 6/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.4037 - accuracy: 0.6406
# Epoch 6
# 2020-09-21T23:14:48.608451+09:00 Train-acc=0.5938
# 2020-09-21T23:14:48.608451+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7111 - accuracy: 0.5938 - val_loss: 6.7727 - val_accuracy: 0.6167
# Epoch 7/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8175 - accuracy: 0.6562
# Epoch 7
# 2020-09-21T23:14:48.657868+09:00 Train-acc=0.5972
# 2020-09-21T23:14:48.657868+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7113 - accuracy: 0.5972 - val_loss: 6.7721 - val_accuracy: 0.6167
# Epoch 8/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.5072 - accuracy: 0.5156
# Epoch 8
# 2020-09-21T23:14:48.707787+09:00 Train-acc=0.5990
# 2020-09-21T23:14:48.707787+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6982 - accuracy: 0.5990 - val_loss: 6.7743 - val_accuracy: 0.6167
# Epoch 9/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.3930 - accuracy: 0.6250
# Epoch 9
# 2020-09-21T23:14:48.757639+09:00 Train-acc=0.5990
# 2020-09-21T23:14:48.757639+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6752 - accuracy: 0.5990 - val_loss: 6.8284 - val_accuracy: 0.6167
# Epoch 10/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.6497 - accuracy: 0.5938
# Epoch 10
# 2020-09-21T23:14:48.808484+09:00 Train-acc=0.6024
# 2020-09-21T23:14:48.808484+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6516 - accuracy: 0.6024 - val_loss: 6.8286 - val_accuracy: 0.6167
# Epoch 11/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.9115 - accuracy: 0.6094
# Epoch 11
# 2020-09-21T23:14:48.863988+09:00 Train-acc=0.6007
# 2020-09-21T23:14:48.863988+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 6ms/step - loss: 6.6460 - accuracy: 0.6007 - val_loss: 6.8284 - val_accuracy: 0.6167
# Epoch 12/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.4566 - accuracy: 0.6406
# Epoch 12
# 2020-09-21T23:14:48.918428+09:00 Train-acc=0.6024
# 2020-09-21T23:14:48.918428+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6346 - accuracy: 0.6024 - val_loss: 6.8276 - val_accuracy: 0.6167
# Epoch 13/100
# 1/9 [==>...........................] - ETA: 0s - loss: 8.3470 - accuracy: 0.5156
# Epoch 13
# 2020-09-21T23:14:48.971803+09:00 Train-acc=0.6024
# 2020-09-21T23:14:48.971803+09:00 Validation-acc=0.6167
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6237 - accuracy: 0.6024 - val_loss: 6.8270 - val_accuracy: 0.6167
# Epoch 14/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.7097 - accuracy: 0.6719
# Epoch 14
# 2020-09-21T23:14:49.024055+09:00 Train-acc=0.6042
# 2020-09-21T23:14:49.024055+09:00 Validation-acc=0.6250
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6203 - accuracy: 0.6042 - val_loss: 6.7770 - val_accuracy: 0.6250
# Epoch 15/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0477 - accuracy: 0.6250
# Epoch 15
# 2020-09-21T23:14:49.076619+09:00 Train-acc=0.6059
# 2020-09-21T23:14:49.076619+09:00 Validation-acc=0.6250
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6080 - accuracy: 0.6059 - val_loss: 6.7701 - val_accuracy: 0.6250
# Epoch 16/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.7053 - accuracy: 0.7031
# Epoch 16
# 2020-09-21T23:14:49.125486+09:00 Train-acc=0.6042
# 2020-09-21T23:14:49.125486+09:00 Validation-acc=0.6333
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6033 - accuracy: 0.6042 - val_loss: 6.7263 - val_accuracy: 0.6333
# Epoch 17/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.5718 - accuracy: 0.6094
# Epoch 17
# 2020-09-21T23:14:49.178739+09:00 Train-acc=0.6076
# 2020-09-21T23:14:49.178739+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5729 - accuracy: 0.6076 - val_loss: 6.6738 - val_accuracy: 0.6417
# Epoch 18/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0738 - accuracy: 0.6250
# Epoch 18
# 2020-09-21T23:14:49.235297+09:00 Train-acc=0.6059
# 2020-09-21T23:14:49.235297+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5664 - accuracy: 0.6059 - val_loss: 6.6609 - val_accuracy: 0.6417
# Epoch 19/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.6526 - accuracy: 0.5625
# Epoch 19
# 2020-09-21T23:14:49.292045+09:00 Train-acc=0.6042
# 2020-09-21T23:14:49.292045+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5523 - accuracy: 0.6042 - val_loss: 6.6559 - val_accuracy: 0.6417
# Epoch 20/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0530 - accuracy: 0.6406
# Epoch 20
# 2020-09-21T23:14:49.351399+09:00 Train-acc=0.6042
# 2020-09-21T23:14:49.351399+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5490 - accuracy: 0.6042 - val_loss: 6.6522 - val_accuracy: 0.6417
# Epoch 21/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.5446 - accuracy: 0.6719
# Epoch 21
# 2020-09-21T23:14:49.406661+09:00 Train-acc=0.6094
# 2020-09-21T23:14:49.406661+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5451 - accuracy: 0.6094 - val_loss: 6.6518 - val_accuracy: 0.6417
# Epoch 22/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0538 - accuracy: 0.6562
# Epoch 22
# 2020-09-21T23:14:49.458393+09:00 Train-acc=0.6146
# 2020-09-21T23:14:49.458393+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5441 - accuracy: 0.6146 - val_loss: 6.6509 - val_accuracy: 0.6417
# Epoch 23/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.9656 - accuracy: 0.6562
# Epoch 23
# 2020-09-21T23:14:49.512437+09:00 Train-acc=0.6146
# 2020-09-21T23:14:49.512437+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5433 - accuracy: 0.6146 - val_loss: 6.6495 - val_accuracy: 0.6417
# Epoch 24/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.4092 - accuracy: 0.5781
# Epoch 24
# 2020-09-21T23:14:49.565622+09:00 Train-acc=0.6146
# 2020-09-21T23:14:49.565622+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5423 - accuracy: 0.6146 - val_loss: 6.6483 - val_accuracy: 0.6417
# Epoch 25/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.9968 - accuracy: 0.5625
# Epoch 25
# 2020-09-21T23:14:49.619910+09:00 Train-acc=0.6146
# 2020-09-21T23:14:49.619910+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5415 - accuracy: 0.6146 - val_loss: 6.6474 - val_accuracy: 0.6417
# Epoch 26/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.3804 - accuracy: 0.5312
# Epoch 26
# 2020-09-21T23:14:49.672729+09:00 Train-acc=0.6128
# 2020-09-21T23:14:49.672729+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5410 - accuracy: 0.6128 - val_loss: 6.6465 - val_accuracy: 0.6417
# Epoch 27/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.7040 - accuracy: 0.4688
# Epoch 27
# 2020-09-21T23:14:49.729360+09:00 Train-acc=0.6128
# 2020-09-21T23:14:49.729360+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5404 - accuracy: 0.6128 - val_loss: 6.6458 - val_accuracy: 0.6417
# Epoch 28/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.6702 - accuracy: 0.6875
# Epoch 28
# 2020-09-21T23:14:49.788822+09:00 Train-acc=0.6128
# 2020-09-21T23:14:49.788822+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.5401 - accuracy: 0.6128 - val_loss: 6.6455 - val_accuracy: 0.6417
# Epoch 29/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.5437 - accuracy: 0.5469
# Epoch 29
# 2020-09-21T23:14:49.857612+09:00 Train-acc=0.6128
# 2020-09-21T23:14:49.857612+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 7ms/step - loss: 6.5395 - accuracy: 0.6128 - val_loss: 6.6448 - val_accuracy: 0.6417
# Epoch 30/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.2260 - accuracy: 0.5625
# Epoch 30
# 2020-09-21T23:14:49.918320+09:00 Train-acc=0.6215
# 2020-09-21T23:14:49.918320+09:00 Validation-acc=0.6333
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4913 - accuracy: 0.6215 - val_loss: 6.6435 - val_accuracy: 0.6333
# Epoch 31/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.9012 - accuracy: 0.6094
# Epoch 31
# 2020-09-21T23:14:49.974534+09:00 Train-acc=0.6215
# 2020-09-21T23:14:49.974534+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4767 - accuracy: 0.6215 - val_loss: 6.6991 - val_accuracy: 0.6417
# Epoch 32/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.6856 - accuracy: 0.6719
# Epoch 32
# 2020-09-21T23:14:50.026080+09:00 Train-acc=0.6181
# 2020-09-21T23:14:50.026080+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4755 - accuracy: 0.6181 - val_loss: 6.6953 - val_accuracy: 0.6417
# Epoch 33/100
# 1/9 [==>...........................] - ETA: 0s - loss: 8.2337 - accuracy: 0.5312
# Epoch 33
# 2020-09-21T23:14:50.078142+09:00 Train-acc=0.6181
# 2020-09-21T23:14:50.078142+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4917 - accuracy: 0.6181 - val_loss: 6.6458 - val_accuracy: 0.6417
# Epoch 34/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.1081 - accuracy: 0.6406
# Epoch 34
# 2020-09-21T23:14:50.127639+09:00 Train-acc=0.6198
# 2020-09-21T23:14:50.127639+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4875 - accuracy: 0.6198 - val_loss: 6.5772 - val_accuracy: 0.6500
# Epoch 35/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.8203 - accuracy: 0.6406
# Epoch 35
# 2020-09-21T23:14:50.178571+09:00 Train-acc=0.6215
# 2020-09-21T23:14:50.178571+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4644 - accuracy: 0.6215 - val_loss: 6.5786 - val_accuracy: 0.6500
# Epoch 36/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8088 - accuracy: 0.7188
# Epoch 36
# 2020-09-21T23:14:50.232930+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.232930+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4618 - accuracy: 0.6250 - val_loss: 6.5795 - val_accuracy: 0.6500
# Epoch 37/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.8391 - accuracy: 0.4688
# Epoch 37
# 2020-09-21T23:14:50.283849+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.283849+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4507 - accuracy: 0.6250 - val_loss: 6.5793 - val_accuracy: 0.6500
# Epoch 38/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.2285 - accuracy: 0.7031
# Epoch 38
# 2020-09-21T23:14:50.342542+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.342542+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4421 - accuracy: 0.6250 - val_loss: 6.5789 - val_accuracy: 0.6500
# Epoch 39/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.7785 - accuracy: 0.6094
# Epoch 39
# 2020-09-21T23:14:50.393672+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.393672+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4152 - accuracy: 0.6250 - val_loss: 6.5784 - val_accuracy: 0.6500
# Epoch 40/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.2693 - accuracy: 0.5938
# Epoch 40
# 2020-09-21T23:14:50.444305+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.444305+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4261 - accuracy: 0.6250 - val_loss: 6.5776 - val_accuracy: 0.6500
# Epoch 41/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0275 - accuracy: 0.6250
# Epoch 41
# 2020-09-21T23:14:50.497279+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.497279+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4145 - accuracy: 0.6250 - val_loss: 6.5769 - val_accuracy: 0.6500
# Epoch 42/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2877 - accuracy: 0.5625
# Epoch 42
# 2020-09-21T23:14:50.546525+09:00 Train-acc=0.6250
# 2020-09-21T23:14:50.546525+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3937 - accuracy: 0.6250 - val_loss: 6.5763 - val_accuracy: 0.6500
# Epoch 43/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1693 - accuracy: 0.6875
# Epoch 43
# 2020-09-21T23:14:50.595811+09:00 Train-acc=0.6267
# 2020-09-21T23:14:50.595811+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3824 - accuracy: 0.6267 - val_loss: 6.5248 - val_accuracy: 0.6500
# Epoch 44/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2554 - accuracy: 0.6094
# Epoch 44
# 2020-09-21T23:14:50.646079+09:00 Train-acc=0.6302
# 2020-09-21T23:14:50.646079+09:00 Validation-acc=0.6500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3422 - accuracy: 0.6302 - val_loss: 6.4708 - val_accuracy: 0.6500
# Epoch 45/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2165 - accuracy: 0.6562
# Epoch 45
# 2020-09-21T23:14:50.696380+09:00 Train-acc=0.6302
# 2020-09-21T23:14:50.696380+09:00 Validation-acc=0.6417
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3270 - accuracy: 0.6302 - val_loss: 6.5799 - val_accuracy: 0.6417
# Epoch 46/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.8004 - accuracy: 0.6094
# Epoch 46
# 2020-09-21T23:14:50.747045+09:00 Train-acc=0.6285
# 2020-09-21T23:14:50.747045+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3282 - accuracy: 0.6285 - val_loss: 6.3805 - val_accuracy: 0.6583
# Epoch 47/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.3551 - accuracy: 0.6875
# Epoch 47
# 2020-09-21T23:14:50.806585+09:00 Train-acc=0.6319
# 2020-09-21T23:14:50.806585+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 6ms/step - loss: 6.2566 - accuracy: 0.6319 - val_loss: 6.3474 - val_accuracy: 0.6583
# Epoch 48/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.7782 - accuracy: 0.6406
# Epoch 48
# 2020-09-21T23:14:50.859595+09:00 Train-acc=0.6319
# 2020-09-21T23:14:50.859595+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2908 - accuracy: 0.6319 - val_loss: 6.3481 - val_accuracy: 0.6667
# Epoch 49/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.6747 - accuracy: 0.6094
# Epoch 49
# 2020-09-21T23:14:50.912093+09:00 Train-acc=0.6302
# 2020-09-21T23:14:50.912093+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2972 - accuracy: 0.6302 - val_loss: 6.3496 - val_accuracy: 0.6667
# Epoch 50/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.3465 - accuracy: 0.5781
# Epoch 50
# 2020-09-21T23:14:50.964998+09:00 Train-acc=0.6302
# 2020-09-21T23:14:50.964998+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2857 - accuracy: 0.6302 - val_loss: 6.3131 - val_accuracy: 0.6667
# Epoch 51/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.6679 - accuracy: 0.7188
# Epoch 51
# 2020-09-21T23:14:51.017515+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.017515+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2850 - accuracy: 0.6302 - val_loss: 6.3168 - val_accuracy: 0.6667
# Epoch 52/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.7149 - accuracy: 0.7656
# Epoch 52
# 2020-09-21T23:14:51.070371+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.070371+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2838 - accuracy: 0.6302 - val_loss: 6.3531 - val_accuracy: 0.6667
# Epoch 53/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1871 - accuracy: 0.6250
# Epoch 53
# 2020-09-21T23:14:51.120514+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.120514+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2826 - accuracy: 0.6302 - val_loss: 6.3132 - val_accuracy: 0.6667
# Epoch 54/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.1061 - accuracy: 0.7500
# Epoch 54
# 2020-09-21T23:14:51.170574+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.170574+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2818 - accuracy: 0.6302 - val_loss: 6.3072 - val_accuracy: 0.6667
# Epoch 55/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.3358 - accuracy: 0.6875
# Epoch 55
# 2020-09-21T23:14:51.220687+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.220687+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2807 - accuracy: 0.6302 - val_loss: 6.3063 - val_accuracy: 0.6667
# Epoch 56/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.2765 - accuracy: 0.5156
# Epoch 56
# 2020-09-21T23:14:51.276869+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.276869+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 6ms/step - loss: 6.2802 - accuracy: 0.6302 - val_loss: 6.3048 - val_accuracy: 0.6667
# Epoch 57/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2845 - accuracy: 0.6250
# Epoch 57
# 2020-09-21T23:14:51.326304+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.326304+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2797 - accuracy: 0.6302 - val_loss: 6.3021 - val_accuracy: 0.6667
# Epoch 58/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.9413 - accuracy: 0.6094
# Epoch 58
# 2020-09-21T23:14:51.377386+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.377386+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2790 - accuracy: 0.6302 - val_loss: 6.3033 - val_accuracy: 0.6667
# Epoch 59/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0593 - accuracy: 0.5781
# Epoch 59
# 2020-09-21T23:14:51.427674+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.427674+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2786 - accuracy: 0.6302 - val_loss: 6.3022 - val_accuracy: 0.6667
# Epoch 60/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.2182 - accuracy: 0.7031
# Epoch 60
# 2020-09-21T23:14:51.479423+09:00 Train-acc=0.6302
# 2020-09-21T23:14:51.479423+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2780 - accuracy: 0.6302 - val_loss: 6.2990 - val_accuracy: 0.6667
# Epoch 61/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1721 - accuracy: 0.6875
# Epoch 61
# 2020-09-21T23:14:51.530752+09:00 Train-acc=0.6319
# 2020-09-21T23:14:51.530752+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2594 - accuracy: 0.6319 - val_loss: 6.2914 - val_accuracy: 0.6667
# Epoch 62/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.5641 - accuracy: 0.6406
# Epoch 62
# 2020-09-21T23:14:51.580851+09:00 Train-acc=0.6319
# 2020-09-21T23:14:51.580851+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2627 - accuracy: 0.6319 - val_loss: 6.2820 - val_accuracy: 0.6667
# Epoch 63/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.8947 - accuracy: 0.5781
# Epoch 63
# 2020-09-21T23:14:51.633647+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.633647+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2616 - accuracy: 0.6354 - val_loss: 6.2796 - val_accuracy: 0.6667
# Epoch 64/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.4205 - accuracy: 0.6562
# Epoch 64
# 2020-09-21T23:14:51.683873+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.683873+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2636 - accuracy: 0.6354 - val_loss: 6.2782 - val_accuracy: 0.6667
# Epoch 65/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0813 - accuracy: 0.7344
# Epoch 65
# 2020-09-21T23:14:51.739561+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.739561+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 6ms/step - loss: 6.2532 - accuracy: 0.6354 - val_loss: 6.2772 - val_accuracy: 0.6667
# Epoch 66/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.2430 - accuracy: 0.6719
# Epoch 66
# 2020-09-21T23:14:51.788878+09:00 Train-acc=0.6372
# 2020-09-21T23:14:51.788878+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.2106 - accuracy: 0.6372 - val_loss: 6.3387 - val_accuracy: 0.6667
# Epoch 67/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8356 - accuracy: 0.6250
# Epoch 67
# 2020-09-21T23:14:51.838113+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.838113+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1933 - accuracy: 0.6354 - val_loss: 6.3361 - val_accuracy: 0.6667
# Epoch 68/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.7654 - accuracy: 0.5469
# Epoch 68
# 2020-09-21T23:14:51.890296+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.890296+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1871 - accuracy: 0.6354 - val_loss: 6.3345 - val_accuracy: 0.6667
# Epoch 69/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2221 - accuracy: 0.6094
# Epoch 69
# 2020-09-21T23:14:51.944221+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.944221+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1856 - accuracy: 0.6354 - val_loss: 6.3344 - val_accuracy: 0.6667
# Epoch 70/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.9192 - accuracy: 0.6406
# Epoch 70
# 2020-09-21T23:14:51.998790+09:00 Train-acc=0.6354
# 2020-09-21T23:14:51.998790+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1845 - accuracy: 0.6354 - val_loss: 6.3342 - val_accuracy: 0.6667
# Epoch 71/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.3885 - accuracy: 0.5625
# Epoch 71
# 2020-09-21T23:14:52.056149+09:00 Train-acc=0.6354
# 2020-09-21T23:14:52.056149+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1840 - accuracy: 0.6354 - val_loss: 6.3338 - val_accuracy: 0.6667
# Epoch 72/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2073 - accuracy: 0.6562
# Epoch 72
# 2020-09-21T23:14:52.108178+09:00 Train-acc=0.6372
# 2020-09-21T23:14:52.108178+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1833 - accuracy: 0.6372 - val_loss: 6.3336 - val_accuracy: 0.6667
# Epoch 73/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.3319 - accuracy: 0.5938
# Epoch 73
# 2020-09-21T23:14:52.158257+09:00 Train-acc=0.6372
# 2020-09-21T23:14:52.158257+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1829 - accuracy: 0.6372 - val_loss: 6.3333 - val_accuracy: 0.6667
# Epoch 74/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8731 - accuracy: 0.6406
# Epoch 74
# 2020-09-21T23:14:52.207740+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.207740+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1759 - accuracy: 0.6389 - val_loss: 6.3331 - val_accuracy: 0.6667
# Epoch 75/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1739 - accuracy: 0.6562
# Epoch 75
# 2020-09-21T23:14:52.269407+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.269407+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1424 - accuracy: 0.6389 - val_loss: 6.3326 - val_accuracy: 0.6667
# Epoch 76/100
# 1/9 [==>...........................] - ETA: 0s - loss: 4.9811 - accuracy: 0.7188
# Epoch 76
# 2020-09-21T23:14:52.320041+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.320041+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1350 - accuracy: 0.6389 - val_loss: 6.3383 - val_accuracy: 0.6667
# Epoch 77/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.9666 - accuracy: 0.6406
# Epoch 77
# 2020-09-21T23:14:52.372701+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.372701+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1452 - accuracy: 0.6389 - val_loss: 6.3942 - val_accuracy: 0.6667
# Epoch 78/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.4100 - accuracy: 0.6406
# Epoch 78
# 2020-09-21T23:14:52.422315+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.422315+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1757 - accuracy: 0.6389 - val_loss: 6.3928 - val_accuracy: 0.6667
# Epoch 79/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1875 - accuracy: 0.6875
# Epoch 79
# 2020-09-21T23:14:52.472079+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.472079+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4603 - accuracy: 0.6389 - val_loss: 6.7089 - val_accuracy: 0.6667
# Epoch 80/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.4428 - accuracy: 0.7188
# Epoch 80
# 2020-09-21T23:14:52.523344+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.523344+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5503 - accuracy: 0.6389 - val_loss: 6.7081 - val_accuracy: 0.6667
# Epoch 81/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1415 - accuracy: 0.6875
# Epoch 81
# 2020-09-21T23:14:52.575729+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.575729+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5886 - accuracy: 0.6389 - val_loss: 6.7076 - val_accuracy: 0.6667
# Epoch 82/100
# 1/9 [==>...........................] - ETA: 0s - loss: 7.3397 - accuracy: 0.6094
# Epoch 82
# 2020-09-21T23:14:52.624724+09:00 Train-acc=0.6406
# 2020-09-21T23:14:52.624724+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6062 - accuracy: 0.6406 - val_loss: 6.7076 - val_accuracy: 0.6667
# Epoch 83/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.7903 - accuracy: 0.5938
# Epoch 83
# 2020-09-21T23:14:52.674684+09:00 Train-acc=0.6389
# 2020-09-21T23:14:52.674684+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.6036 - accuracy: 0.6389 - val_loss: 6.7074 - val_accuracy: 0.6667
# Epoch 84/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.7756 - accuracy: 0.6875
# Epoch 84
# 2020-09-21T23:14:52.729462+09:00 Train-acc=0.6406
# 2020-09-21T23:14:52.729462+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 6ms/step - loss: 6.6058 - accuracy: 0.6406 - val_loss: 6.7092 - val_accuracy: 0.6667
# Epoch 85/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.0749 - accuracy: 0.7812
# Epoch 85
# 2020-09-21T23:14:52.779586+09:00 Train-acc=0.6424
# 2020-09-21T23:14:52.779586+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5955 - accuracy: 0.6424 - val_loss: 6.7148 - val_accuracy: 0.6667
# Epoch 86/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.2979 - accuracy: 0.6875
# Epoch 86
# 2020-09-21T23:14:52.830045+09:00 Train-acc=0.6424
# 2020-09-21T23:14:52.830045+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5942 - accuracy: 0.6424 - val_loss: 6.7034 - val_accuracy: 0.6667
# Epoch 87/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.4910 - accuracy: 0.6094
# Epoch 87
# 2020-09-21T23:14:52.880579+09:00 Train-acc=0.6458
# 2020-09-21T23:14:52.880579+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.5078 - accuracy: 0.6458 - val_loss: 6.7029 - val_accuracy: 0.6667
# Epoch 88/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1135 - accuracy: 0.5312
# Epoch 88
# 2020-09-21T23:14:52.932530+09:00 Train-acc=0.6458
# 2020-09-21T23:14:52.932530+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4279 - accuracy: 0.6458 - val_loss: 6.5122 - val_accuracy: 0.6667
# Epoch 89/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.3724 - accuracy: 0.5625
# Epoch 89
# 2020-09-21T23:14:52.983486+09:00 Train-acc=0.6476
# 2020-09-21T23:14:52.983486+09:00 Validation-acc=0.6667
# 9/9 [==============================] - 0s 5ms/step - loss: 6.1808 - accuracy: 0.6476 - val_loss: 6.3847 - val_accuracy: 0.6667
# Epoch 90/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8368 - accuracy: 0.6875
# Epoch 90
# 2020-09-21T23:14:53.032979+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.032979+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0723 - accuracy: 0.6493 - val_loss: 6.3255 - val_accuracy: 0.6583
# Epoch 91/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.6499 - accuracy: 0.6562
# Epoch 91
# 2020-09-21T23:14:53.085834+09:00 Train-acc=0.6476
# 2020-09-21T23:14:53.085834+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0926 - accuracy: 0.6476 - val_loss: 6.2695 - val_accuracy: 0.6583
# Epoch 92/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.7194 - accuracy: 0.7031
# Epoch 92
# 2020-09-21T23:14:53.136038+09:00 Train-acc=0.6476
# 2020-09-21T23:14:53.136038+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0856 - accuracy: 0.6476 - val_loss: 6.2666 - val_accuracy: 0.6583
# Epoch 93/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8394 - accuracy: 0.6875
# Epoch 93
# 2020-09-21T23:14:53.188010+09:00 Train-acc=0.6476
# 2020-09-21T23:14:53.188010+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0958 - accuracy: 0.6476 - val_loss: 6.2659 - val_accuracy: 0.6583
# Epoch 94/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.9152 - accuracy: 0.6719
# Epoch 94
# 2020-09-21T23:14:53.244846+09:00 Train-acc=0.6476
# 2020-09-21T23:14:53.244846+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 6ms/step - loss: 6.0814 - accuracy: 0.6476 - val_loss: 6.2650 - val_accuracy: 0.6583
# Epoch 95/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.4245 - accuracy: 0.6406
# Epoch 95
# 2020-09-21T23:14:53.296769+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.296769+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0910 - accuracy: 0.6493 - val_loss: 6.3273 - val_accuracy: 0.6583
# Epoch 96/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.0378 - accuracy: 0.5938
# Epoch 96
# 2020-09-21T23:14:53.346780+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.346780+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0890 - accuracy: 0.6493 - val_loss: 6.3267 - val_accuracy: 0.6583
# Epoch 97/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.1948 - accuracy: 0.6406
# Epoch 97
# 2020-09-21T23:14:53.398622+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.398622+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0877 - accuracy: 0.6493 - val_loss: 6.3262 - val_accuracy: 0.6583
# Epoch 98/100
# 1/9 [==>...........................] - ETA: 0s - loss: 6.9209 - accuracy: 0.5781
# Epoch 98
# 2020-09-21T23:14:53.450305+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.450305+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0867 - accuracy: 0.6493 - val_loss: 6.3258 - val_accuracy: 0.6583
# Epoch 99/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.4915 - accuracy: 0.6875
# Epoch 99
# 2020-09-21T23:14:53.499515+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.499515+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0858 - accuracy: 0.6493 - val_loss: 6.3254 - val_accuracy: 0.6583
# Epoch 100/100
# 1/9 [==>...........................] - ETA: 0s - loss: 5.8436 - accuracy: 0.6562
# Epoch 100
# 2020-09-21T23:14:53.548110+09:00 Train-acc=0.6493
# 2020-09-21T23:14:53.548110+09:00 Validation-acc=0.6583
# 9/9 [==============================] - 0s 5ms/step - loss: 6.0850 - accuracy: 0.6493 - val_loss: 6.3251 - val_accuracy: 0.6583

# %% [markdown]
# <a id='AutoDL_사용방법'></a>
# ## Modeler AutoDL 사용방법
# - 지금까지 스팸 계정과 정상 계정을 분류하는 MLP 모델 예제를 살펴보았습니다.
# - 이번 챕터에서는 위에서 살펴본 MLP 모델의 하이퍼파라미터를 AutoDL 기능을 사용해 최적화하는 과정에 대해 다룰 것입니다.
